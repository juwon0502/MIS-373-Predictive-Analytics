# %%
import tensorflow as tf

mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()


x_train = tf.keras.utils.normalize(x_train, axis = 1)
x_test = tf.keras.utils.normalize(x_test, axis = 1)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer="adam",
              loss="sparse_categorical_crossentropy",
              metrics=['accuracy'])

model.fit(x_train, y_train, epochs=3)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 2s 0us/step
# 11501568/11490434 [==============================] - 2s 0us/step
# Epoch 1/3
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.2627 - accuracy: 0.9227
# Epoch 2/3
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.1059 - accuracy: 0.9669
# Epoch 3/3
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.0706 - accuracy: 0.9779

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss, val_acc)


# model.predict(x_test, y_test)
# Out:
# 313/313 [==============================] - 1s 1ms/step - loss: 0.0978 - accuracy: 0.9691
# 0.09778617322444916 0.9690999984741211

# %%
from matplotlib import pyplot as plt

plt.imshow(x_train[0], cmap=plt.cm.binary)
plt.show()

# %%
predictions = model.predict([x_test])
print(predictions)
# Out:
# WARNING:tensorflow:Layers in a Sequential model should only have a single input tensor, but we receive a <class 'tuple'> input: (<tf.Tensor 'IteratorGetNext:0' shape=(None, 28, 28) dtype=float32>,)
# Consider rewriting this model with the Functional API.
# [[7.65141905e-09 6.44856541e-08 6.83849657e-06 ... 9.99914885e-01
#   7.98290944e-09 6.93011170e-05]
#  [9.17661254e-08 1.09277305e-03 9.98847365e-01 ... 3.90009891e-09
#   1.29252658e-06 5.89133520e-10]
#  [1.95029841e-08 9.99838352e-01 2.75678885e-05 ... 5.49747710e-05
#   4.63460092e-05 7.69293933e-07]
#  ...
#  [1.19777976e-09 4.37497903e-07 3.71004987e-08 ... 8.78249557e-06
#   3.67574248e-05 4.33185603e-03]
#  [1.69026293e-07 2.31410141e-07 1.84871851e-08 ... 6.19148963e-08
#   2.09287694e-03 1.07786114e-07]
#  [9.49625587e-07 2.83820185e-08 1.02660317e-06 ... 2.74448825e-10
#   7.01404417e-07 2.75727928e-07]]

# %%
import numpy as np

print(np.argmax(predictions[0]))
# Out:
# 7

# %%
plt.imshow(x_test[0])
plt.show()

# %%
predictions = model.predict([x_test])
for x in range(len(x_test)):
  if np.argmax(predictions[x]) != y_test[x]:
    plt.imshow(x_test[x])
    plt.show()
    print(f"Predicition: {np.argmax(predictions[x])}")
    print(f"Actual: {y_test[x]}")
# Out:
# Predicition: 9
# Actual: 4
# Predicition: 7
# Actual: 2
# Predicition: 3
# Actual: 5
# Predicition: 7
# Actual: 3
# Predicition: 8
# Actual: 2
# Predicition: 9
# Actual: 4
# Predicition: 2
# Actual: 8
# Predicition: 7
# Actual: 2
# Predicition: 6
# Actual: 4
# Predicition: 8
# Actual: 2
# Predicition: 8
# Actual: 1
# Predicition: 3
# Actual: 7
# Predicition: 4
# Actual: 8
# Predicition: 6
# Actual: 0
# Predicition: 8
# Actual: 5
# Predicition: 8
# Actual: 2
# Predicition: 9
# Actual: 4
# Predicition: 9
# Actual: 4
# Predicition: 7
# Actual: 8
# Predicition: 9
# Actual: 7
# Predicition: 3
# Actual: 1
# Predicition: 7
# Actual: 2
# Predicition: 9
# Actual: 8
# Predicition: 9
# Actual: 5
# Predicition: 8
# Actual: 4
# Predicition: 3
# Actual: 2
# Predicition: 9
# Actual: 6
# Predicition: 8
# Actual: 5
# Predicition: 1
# Actual: 7
# Predicition: 8
# Actual: 6
# Predicition: 6
# Actual: 4
# Predicition: 8
# Actual: 7
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual:
# Predicition: 9
# Actual: 4
# Predicition: 9
# Actual: 4
# Predicition: 8
# Actual: 3
# Predicition: 8
# Actual: 3
# Predicition: 9
# Actual: 5
# Predicition: 3
# Actual: 5
# Predicition: 9
# Actual: 5
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 3
# Predicition: 0
# Actual: 2
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 5
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 5
# Predicition: 9
# Actual: 5
# Predicition: 9
# Actual: 8
# Predicition: 7
# Actual: 9
# Predicition: 6
# Actual: 2
# Predicition: 1
# Actual: 7
# Predicition: 7
# Actual: 0
# Predicition: 9
# Actual: 8
# Predicition: 4
# Actual: 8
# Predicition: 8
# Actual: 0
# Predicition: 6
# Actual: 1
# Predicition: 4
# Actual: 6
# Predicition: 6
# Actual: 0
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 4
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 4
# Predicition: 2
# Actual: 7
# Predicition: 8
# Actual: 4
# Predicition: 6
# Actual: 5
# Predicition: 8
# Actual: 2
# Predicition: 7
# Actual: 2
# Predicition: 8
# Actual: 3
# Predicition: 3
# Actual: 2
# Predicition: 8
# Actual: 5
# Predicition: 8
# Actual: 1
# Predicition: 8
# Actual: 1
# Predicition: 8
# Actual: 7
# Predicition: 8
# Actual: 7
# Predicition: 8
# Actual: 1
# Predicition: 8
# Actual: 1
# Predicition: 1
# Actual: 2
# Predicition: 8
# Actual: 5
# Predicition: 8
# Actual: 2
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 3
# Predicition: 4
# Actual: 6
# Predicition: 6
# Actual: 0
# Predicition: 5
# Actual: 3
# Predicition: 9
# Actual: 4
# Predicition: 6
# Actual: 8
# Predicition: 6
# Actual: 8
# Predicition: 8
# Actual: 5
# Predicition: 8
# Actual: 1
# Predicition: 8
# Actual: 1
# Predicition: 9
# Actual: 4
# Predicition: 9
# Actual: 3
# Predicition: 2
# Actual: 7
# Predicition: 2
# Actual: 7
# Predicition: 2
# Actual: 7
# Predicition: 8
# Actual: 1
# Predicition: 9
# Actual: 3
# Predicition: 9
# Actual: 4
# Predicition: 5
# Actual: 8
# Predicition: 8
# Actual: 5
# Predicition: 3
# Actual: 5
# Predicition: 9
# Actual: 4
# Predicition: 8
# Actual: 1
# Predicition: 4
# Actual: 9
# Predicition: 8
# Actual: 0
# Predicition: 9
# Actual: 7
# Predicition: 3
# Actual: 6
# Predicition: 8
# Actual: 2
# Predicition: 3
# Actual: 2
# Predicition: 6
# Actual: 5
# Predicition: 2
# Actual: 4
# Predicition: 6
# Actual: 5
# Predicition: 9
# Actual: 4
# Predicition: 0
# Actual: 2
# Predicition: 0
# Actual: 5
# Predicition: 0
# Actual: 2
# Predicition: 7
# Actual: 4
# Predicition: 8
# Actual: 2
# Predicition: 7
# Actual: 2
# Predicition: 6
# Actual: 0
# Predicition: 8
# Actual: 2
# Predicition: 0
# Actual: 2
# Predicition: 9
# Actual: 3
# Predicition: 8
# Actual: 3
# Predicition: 3
# Actual: 2
# Predicition: 6
# Actual: 5
